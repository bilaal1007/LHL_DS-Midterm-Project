# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import os

US_data = pd.read_csv(f"{os.path.abspath('../data/filtered_US_data.csv')}")
# Create a pairplot
sns.pairplot(US_data)
plt.show()
# Out:
# C:\Users\mario\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
symbols = list(US_data['Ticker Symbol'].unique())
print(symbols)
# Out:
# ['AAPL', 'MSFT', 'GOOG', 'AMZN', 'NVDA', 'META', 'TSLA', 'LLY', 'UNH', 'V', 'WMT', 'XOM', 'JPM', 'JNJ', 'PG', 'MA', 'AVGO', 'HD', 'ORCL', 'CVX', 'MRK', 'ABBV', 'COST', 'KO', 'ADBE', 'PEP', 'CSCO', 'BAC', 'CRM', 'MCD', 'NFLX', 'PFE', 'TMO', 'TMUS', 'CMCSA', 'ABT', 'AMD', 'NKE', 'INTC', 'DIS', 'VZ', 'WFC', 'COP', 'DHR', 'INTU', 'PM', 'AMGN', 'IBM', 'TXN', 'UNP', 'QCOM', 'HON', 'UPS', 'NOW', 'GE', 'NEE', 'RTX', 'CAT', 'MS', 'BA', 'LMT', 'SPGI', 'AMAT', 'T', 'LOW', 'AXP', 'ELV', 'SBUX', 'DE', 'BMY', 'SYK', 'TJX', 'GS', 'BKNG', 'GILD', 'SCHW', 'MMC', 'VRTX', 'PLD', 'PGR', 'ISRG', 'CI', 'BLK', 'MDLZ', 'ADP', 'CVS', 'UBER', 'REGN', 'AMT', 'SLB', 'ADI', 'LRCX', 'CME', 'C', 'PANW', 'ABNB', 'BSX', 'EOG', 'MU', 'SO', 'BDX', 'ZTS', 'SNPS', 'NOC', 'MO', 'DUK', 'EQIX', 'FI', 'ITW', 'BX', 'WM', 'GD', 'CDNS', 'HUM', 'KLAC', 'VMW', 'APD', 'ANET', 'KKR', 'CL', 'MCK', 'ICE', 'SHW', 'HCA', 'MPC', 'FDX', 'CHTR', 'CSX', 'PYPL', 'EPD', 'MCO', 'MAR', 'PXD', 'ORLY', 'WDAY', 'SCCO', 'OXY', 'MNST', 'CMG', 'ROP
# ...

# %%
companies_data = [
    {"symbol": "AAPL", "GICSsector": "Information Technology", "company_name": "Apple Inc."},
    {"symbol": "MSFT", "GICSsector": "Information Technology", "company_name": "Microsoft Corporation"},
    {"symbol": "GOOG", "GICSsector": "Communication Services", "company_name": "Alphabet Inc."},
    {"symbol": "AMZN", "GICSsector": "Consumer Discretionary", "company_name": "Amazon.com Inc."},
    {"symbol": "NVDA", "GICSsector": "Information Technology", "company_name": "NVIDIA Corporation"},
    {"symbol": "META", "GICSsector": "Communication Services", "company_name": "Meta Platforms Inc."},
    {"symbol": "TSLA", "GICSsector": "Consumer Discretionary", "company_name": "Tesla, Inc."},
    {"symbol": "LLY", "GICSsector": "Health Care", "company_name": "Eli Lilly and Company"},
    {"symbol": "UNH", "GICSsector": "Health Care", "company_name": "UnitedHealth Group Incorporated"},
    {"symbol": "V", "GICSsector": "Information Technology", "company_name": "Visa Inc."},
    {"symbol": "WMT", "GICSsector": "Consumer Staples", "company_name": "Walmart Inc."},
    {"symbol": "XOM", "GICSsector": "Energy", "company_name": "Exxon Mobil Corporation"},
    {"symbol": "JPM", "GICSsector": "Financials", "company_name": "JPMorgan Chase & Co."},
    {"symbol": "JNJ", "GICSsector": "Health Care", "company_name": "Johnson & Johnson"},
    {"symbol": "PG", "GICSsector": "Consumer Staples", "company_name": "Procter & Gamble Company"},
    {"symbol": "MA", "GICSsector": "Information Technology", "company_name": "Mastercard Incorporated"},
    {"symbol": "AVGO", "GICSsector": "Information Technology", "company_name": "Broadcom Inc."},
    {"symbol": "HD", "GICSsector": "Consumer Discretionary", "company_name": "The Home Depot, Inc."},
    {"symbol": "ORCL", "GICSsector": "Information Technology", "company_name": "Oracle Corporation"},
    {"symbol": "CVX", "GICSsector": "Energy", "company_name": "Chevron Corporation"},
    {"symbol": "MRK", "GICSsector": "Health Care", "company_name": "Merck & Co., Inc."},
    {"symbol": "ABBV", "GICSsector": "Health Care", "company_name": "AbbVie Inc."},
    {"symbol": "COST", "GICSsector": "Consumer Staples", "company_name": "Costco Wholesale Corporation"},
    {"symbol": "KO", "GICSsector": "Consumer Staples", "company_name": "The Coca-Cola Company"},
    {"symbol": "ADBE", "GICSsector": "Information Technology", "company_name": "Adobe Inc."},
    {"symbol": "PEP", "GICSsector": "Consumer Staples", "company_name": "PepsiCo, Inc."},
    {"symbol": "CSCO", "GICSsector": "Information Technology", "company_name": "Cisco Systems, Inc."},
    {"symbol": "BAC", "GICSsector": "Financials", "company_name": "Bank of America Corporation"},
    {"symbol": "CRM", "GICSsector": "Information Technology", "company_name": "Salesforce.com, inc."},
    {"symbol": "MCD", "GICSsector": "Consumer Discretionary", "company_name": "McDonald's Corporation"},
    {"symbol": "NFLX", "GICSsector": "Communication Services", "company_name": "Netflix, Inc."},
    {"symbol": "PFE", "GICSsector": "Health Care", "company_name": "Pfizer Inc."},
    {"symbol": "TMO", "GICSsector": "Health Care", "company_name": "Thermo Fisher Scientific Inc."},
    {"symbol": "TMUS", "GICSsector": "Communication Services", "company_name": "T-Mobile US, Inc."},
    {"symbol": "CMCSA", "GICSsector": "Communication Services", "company_name": "Comcast Corporation"},
    {"symbol": "ABT", "GICSsector": "Health Care", "company_name": "Abbott Laboratories"},
    {"symbol": "AMD", "GICSsector": "Information Technology", "company_name": "Advanced Micro Devices, Inc."},
    {"symbol": "NKE", "GICSsector": "Consumer Discretionary", "company_name": "NIKE, Inc."},
    {"symbol": "INTC", "GICSsector": "Information Technology", "company_name": "Intel Corporation"},
    {"symbol": "DIS", "GICSsector": "Communication Services", "company_name": "The Walt Disney Company"},
    {"symbol": "VZ", "GICSsector": "Communication Services", "company_name": "Verizon Communications Inc."},
    {"symbol": "WFC", "GICSsector": "Financials", "company_name": "Wells Fargo & Company"},
    {"symbol": "COP", "GICSsector": "Energy", "company_name": "ConocoPhillips"},
    {"symbol": "DHR", "GICSsector": "Health Care", "company_name": "Danaher Corporation"},
    {"symbol": "INTU", "GICSsector": "Information Technology", "company_name": "Intuit Inc."},
    {"symbol": "PM", "GICSsector": "Consumer Staples", "company_name": "Philip Morris International Inc."},
    {"symbol": "AMGN", "GICSsector": "Health Care", "company_name": "Amgen Inc."},
    {"symbol": "IBM", "GICSsector": "Information Technology", "company_name": "International Business Machines Corporation"},
    {"symbol": "TXN", "GICSsector": "Information Technology", "company_name": "Texas Instruments Incorporated"},
      {"symbol": "UNP", "GICSsector": "Industrials", "company_name": "Union Pacific Corporation"},
    {"symbol": "QCOM", "GICSsector": "Information Technology", "company_name": "QUALCOMM Incorporated"},
    {"symbol": "HON", "GICSsector": "Industrials", "company_name": "Honeywell International Inc."},
    {"symbol": "UPS", "GICSsector": "Industrials", "company_name": "United Parcel Service, Inc."},
    {"symbol": "NOW", "GICSsector": "Information Technology", "company_name": "ServiceNow, Inc."},
    {"symbol": "GE", "GICSsector": "Industrials", "company_name": "General Electric Company"},
    {"symbol": "NEE", "GICSsector": "Utilities", "company_name": "NextEra Energy, Inc."},
    {"symbol": "RTX", "GICSsector": "Industrials", "company_name": "Raytheon Technologies Corporation"},
    {"symbol": "CAT", "GICSsector": "Industrials", "company_name": "Caterpillar Inc."},
    {"symbol": "MS", "GICSsector": "Financials", "company_name": "Morgan Stanley"},
    {"symbol": "BA", "GICSsector": "Industrials", "company_name": "The Boeing Company"},
    {"symbol": "LMT", "GICSsector": "Industrials", "company_name": "Lockheed Martin Corporation"},
    {"symbol": "SPGI", "GICSsector": "Financials", "company_name": "S&P Global Inc."},
    {"symbol": "AMAT", "GICSsector": "Information Technology", "company_name": "Applied Materials, Inc."},
    {"symbol": "T", "GICSsector": "Communication Services", "company_name": "AT&T Inc."},
    {"symbol": "LOW", "GICSsector": "Consumer Discretionary", "company_name": "Lowe's Companies, Inc."},
    {"symbol": "AXP", "GICSsector": "Financials", "company_name": "American Express Company"},
    {"symbol": "ELV", "GICSsector": "Industrials", "company_name": "Elbit Systems Ltd."},
    {"symbol": "SBUX", "GICSsector": "Consumer Discretionary", "company_name": "Starbucks Corporation"},
    {"symbol": "DE", "GICSsector": "Consumer Discretionary", "company_name": "Deere & Company"},
    {"symbol": "BMY", "GICSsector": "Health Care", "company_name": "Bristol-Myers Squibb Company"},
    {"symbol": "SYK", "GICSsector": "Health Care", "company_name": "Stryker Corporation"},
    {"symbol": "TJX", "GICSsector": "Consumer Discretionary", "company_name": "TJX Companies Inc."},
    {"symbol": "GS", "GICSsector": "Financials", "company_name": "The Goldman Sachs Group, Inc."},
    {"symbol": "BKNG", "GICSsector": "Consumer Discretionary", "company_name": "Booking Holdings Inc."},
    {"symbol": "GILD", "GICSsector": "Health Care", "company_name": "Gilead Sciences, Inc."},
    {"symbol": "SCHW", "GICSsector": "Financials", "company_name": "The Charles Schwab Corporation"},
    {"symbol": "MMC", "GICSsector": "Financials", "company_name": "Marsh & McLennan Companies, Inc."},
    {"symbol": "VRTX", "GICSsector": "Health Care", "company_name": "Vertex Pharmaceuticals Incorporated"},
    {"symbol": "PLD", "GICSsector": "Real Estate", "company_name": "Prologis, Inc."},
    {"symbol": "PGR", "GICSsector": "Financials", "company_name": "The Progressive Corporation"},
    {"symbol": "ISRG", "GICSsector": "Health Care", "company_name": "Intuitive Surgical, Inc."},
    {"symbol": "CI", "GICSsector": "Health Care", "company_name": "Cigna Corporation"},
    {"symbol": "BLK", "GICSsector": "Financials", "company_name": "BlackRock, Inc."},
    {"symbol": "MDLZ", "GICSsector": "Consumer Staples", "company_name": "Mondelez International, Inc."},
    {"symbol": "ADP", "GICSsector": "Information Technology", "company_name": "Automatic Data Processing, Inc."},
    {"symbol": "CVS", "GICSsector": "Health Care", "company_name": "CVS Health Corporation"},
    {"symbol": "UBER", "GICSsector": "Industrials", "company_name": "Uber Technologies, Inc."},
    {"symbol": "REGN", "GICSsector": "Health Care", "company_name": "Regeneron Pharmaceuticals, Inc."},
    {"symbol": "AMT", "GICSsector": "Real Estate", "company_name": "American Tower Corporation"},
    {"symbol": "SLB", "GICSsector": "Energy", "company_name": "Schlumberger Limited"},
    {"symbol": "ADI", "GICSsector": "Information Technology", "company_name": "Analog Devices, Inc."},
    {"symbol": "LRCX", "GICSsector": "Information Technology", "company_name": "Lam Research Corporation"},
    {"symbol": "C", "GICSsector": "Financials", "company_name": "Citigroup Inc."},
    {"symbol": "PANW", "GICSsector": "Information Technology", "company_name": "Palo Alto Networks, Inc."},
    {"symbol": "ABNB", "GICSsector": "Industrials", "company_name": "Airbnb, Inc."},
    {"symbol": "BSX", "GICSsector": "Health Care", "company_name": "Boston Scientific Corporation"},
    {"symbol": "EOG", "GICSsector": "Energy", "company_name": "EOG Resources, Inc."},
    {"symbol": "MU", "GICSsector": "Information Technology", "company_name": "Micron Technology, Inc."},
    {"symbol": "SO", "GICSsector": "Utilities", "company_name": "The Southern Company"},
    {"symbol": "BDX", "GICSsector": "Health Care", "company_name": "Becton, Dickinson and Company"},
    {"symbol": "ZTS", "GICSsector": "Health Care", "company_name": "Zoetis Inc."},
    {"symbol": "SNPS", "GICSsector": "Information Technology", "company_name": "Synopsys, Inc."},
    {"symbol": "NOC", "GICSsector": "Industrials", "company_name": "Northrop Grumman Corporation"},
    {"symbol": "MO", "GICSsector": "Consumer Staples", "company_name": "Altria Group, Inc."},
    {"symbol": "DUK", "GICSsector": "Utilities", "company_name": "Duke Energy Corporation"},
    {"symbol": "EQIX", "GICSsector": "Real Estate", "company_name": "Equinix, Inc."},
    {"symbol": "FI", "GICSsector": "Financials", "company_name": "Franklin Resources, Inc."},
    {"symbol": "ITW", "GICSsector": "Industrials", "company_name": "Illinois Tool Works Inc."},
    {"symbol": "BX", "GICSsector": "Financials", "company_name": "The Blackstone Group Inc."},
    {"symbol": "WM", "GICSsector": "Industrials", "company_name": "Waste Management, Inc."},
    {"symbol": "GD", "GICSsector": "Industrials", "company_name": "General Dynamics Corporation"},
    {"symbol": "CDNS", "GICSsector": "Information Technology", "company_name": "Cadence Design Systems, Inc."},
    {"symbol": "HUM", "GICSsector": "Health Care", "company_name": "Humana Inc."},
    {"symbol": "KLAC", "GICSsector": "Information Technology", "company_name": "KLA Corporation"},
    {"symbol": "VMW", "GICSsector": "Information Technology", "company_name": "VMware, Inc."},
    {"symbol": "APD", "GICSsector": "Materials", "company_name": "Air Products and Chemicals, Inc."},
    {"symbol": "ANET", "GICSsector": "Information Technology", "company_name": "Arista Networks, Inc."},
    {"symbol": "KKR", "GICSsector": "Financials", "company_name": "KKR & Co. Inc."},
    {"symbol": "CL", "GICSsector": "Consumer Staples", "company_name": "Colgate-Palmolive Company"},
    {"symbol": "MCK", "GICSsector": "Health Care", "company_name": "McKesson Corporation"},
    {"symbol": "ICE", "GICSsector": "Financials", "company_name": "Intercontinental Exchange, Inc."},
    {"symbol": "SHW", "GICSsector": "Materials", "company_name": "The Sherwin-Williams Company"},
    {"symbol": "HCA", "GICSsector": "Health Care", "company_name": "HCA Healthcare, Inc."},
    {"symbol": "MPC", "GICSsector": "Energy", "company_name": "Marathon Petroleum Corporation"},
    {"symbol": "FDX", "GICSsector": "Industrials", "company_name": "FedEx Corporation"},
    {"symbol": "CHTR", "GICSsector": "Communication Services", "company_name": "Charter Communications, Inc."},
    {"symbol": "CSX", "GICSsector": "Industrials", "company_name": "CSX Corporation"},
    {"symbol": "PYPL", "GICSsector": "Information Technology", "company_name": "PayPal Holdings, Inc."},
    {"symbol": "EPD", "GICSsector": "Energy", "company_name": "Enterprise Products Partners L.P."},
    {"symbol": "MCO", "GICSsector": "Financials", "company_name": "Moody's Corporation"},
    {"symbol": "MAR", "GICSsector": "Consumer Discretionary", "company_name": "Marriott International, Inc."},
    {"symbol": "PXD", "GICSsector": "Energy", "company_name": "Pioneer Natural Resources Company"},
    {"symbol": "ORLY", "GICSsector": "Consumer Discretionary", "company_name": "O'Reilly Automotive"}
    
]
Companies = pd.DataFrame(companies_data)

# %%
Companies
# Out:
#     symbol              GICSsector                       company_name
# 0     AAPL  Information Technology                         Apple Inc.
# 1     MSFT  Information Technology              Microsoft Corporation
# 2     GOOG  Communication Services                      Alphabet Inc.
# 3     AMZN  Consumer Discretionary                    Amazon.com Inc.
# 4     NVDA  Information Technology                 NVIDIA Corporation
# ..     ...                     ...                                ...
# 128    EPD                  Energy  Enterprise Products Partners L.P.
# 129    MCO              Financials                Moody's Corporation
# 130    MAR  Consumer Discretionary       Marriott International, Inc.
# 131    PXD                  Energy  Pioneer Natural Resources Company
# 132   ORLY  Consumer Discretionary                O'Reilly Automotive
#
# [133 rows x 3 columns]

# %%
print(*Companies['symbol'].isin(symbols))
# Out:
# True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True True

# %%
for i in range(len(symbols)):
    print(Companies['symbol'][i] == symbols[i])
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
symbols[1]
# Out:
# 'MSFT'

# %%
Companies.to_csv(f"{os.path.abspath('../data/GICScategories.csv')}",index=False)

# %%
US_data
# Out:
#               Date Company Name Ticker Symbol  Oct2023 Market Cap     Open  \
# 0       2021-11-01        Apple          AAPL        2.669000e+12  148.985
# 1       2021-11-02        Apple          AAPL        2.669000e+12  148.660
# 2       2021-11-03        Apple          AAPL        2.669000e+12  150.390
# 3       2021-11-04        Apple          AAPL        2.669000e+12  151.580
# 4       2021-11-05        Apple          AAPL        2.669000e+12  151.890
# ...            ...          ...           ...                 ...      ...
# 247624  2023-10-24    AspenTech          AZPN        1.133000e+10  179.000
# 247625  2023-10-25    AspenTech          AZPN        1.133000e+10  178.010
# 247626  2023-10-26    AspenTech          AZPN        1.133000e+10  177.190
# 247627  2023-10-27    AspenTech          AZPN        1.133000e+10  179.460
# 247628  2023-10-30    AspenTech          AZPN        1.133000e+10  180.430
#
#             Low     High   Close      Volume  Daily Percent Change
# ...
